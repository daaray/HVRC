# %%
pax_entries = [
    'Bellhop',
    'Quicken',
    'MLP',
    'MLP',
    'Nacho Libre',
    'Nacho Libre',
    'The Exchange',
    'Wreckless',
    'Wreckless',
    'TB',
    'TB',
    'Dean Wormer',
    'Elf',
    'Elf',
    'Elf',
    'Doogie',
    'Marta',
    'Bartman',
    'TB',
    'TB',
    'Green Acres',
    'Green Acres',
    'Griswold',
    'Griswold',
    'Stop Drop and Roll',
    'Stop Drop and Roll',
    'Malware',
    'Malware',
    'Cosmo',
    'Uzi',
    'Uzi',
    'Doogie',
    'Peppermint Pattie',
    'Cortes',
    'Enigma',
    'Enigma',
    'Enigma',
    'Commodore',
    'Commodore',
    'Red October',
    'Red October',
    'DOI',
    'DOI',
    'Slayer',
    'Slayer',
    'Pikachu',
    'Pikachu',
    'Exhibit A',
    'Cortes',
    'Enigma',
    'Enigma',
    'One Direction',
    'One Direction',    
]

entries = len(pax_entries)
print(f'There are {entries} entries!')
# Out:
# There are 53 entries!

# %%
import random
import time

import pandas as pd 

picks = {x:0 for x in pax_entries}
spaces = " " * 100

for x in range(2000):
    selection = random.choice(pax_entries)
    print(f"Testing the randomness: {selection} {spaces}", end="\r", flush=True)
    time.sleep(.005)
    picks[selection] += 1

print(f"Testing complete! {spaces}", end="\r", flush=True)

pax_series = pd.Series(list(picks.keys()))
tickets_series = pd.Series(list(picks.values()))
  
data = { 'PAX': pax_series, 'PULLS': tickets_series }     
df = pd.DataFrame(data) 
df.plot.bar(x='PAX', y='PULLS', figsize = (20, 10))
# Out:
# Testing complete!

# %%
print("Picking Primo Winnero...")
time.sleep(2)
selection = random.choice(pax_entries)
print(f"First Prize goes to: {selection}")
# Out:
# Picking Primo Winnero...
# First Prize goes to: Malware

# %%
# removing previous winner from the pool.
pax_entries = [x for x in pax_entries if x != selection]
print("Picking Secundo Weiner...")
time.sleep(2)
selection = random.choice(pax_entries)
print(f"Second Prize goes to: {selection}")
# Out:
# Picking Secundo Weiner...
# Second Prize goes to: Elf

# %%
# removing previous winner from the pool.
pax_entries = [x for x in pax_entries if x != selection]
print("Picking Tri Vinner...")
time.sleep(2)
selection = random.choice(pax_entries)
print(f"Third Prize goes to: {selection}")
# Out:
# Picking Tri Vinner...
# Third Prize goes to: Cortes
